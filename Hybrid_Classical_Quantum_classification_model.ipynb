# %% [markdown]
# ## Image preprocessing code (we have already preprocessed and hosted the dataset on roboflow) so you do not need to run this code explicitly

# %%
class ImageProcessing:
    def __init__(self, img_height, img_width, no_channels, tol=10, sigmaX=10):

        ''' Initialzation of variables'''

        self.img_height = img_height
        self.img_width = img_width
        self.no_channels = no_channels
        self.tol = tol
        self.sigmaX = sigmaX

    def cropping_2D(self, img, is_cropping = False):

        '''This function is used for Cropping the extra dark part of the GRAY images'''

        mask = img>self.tol
        return img[np.ix_(mask.any(1),mask.any(0))]

    def cropping_3D(self, img, is_cropping = False):

        '''This function is used for Cropping the extra dark part of the RGB images'''

        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        mask = gray_img>self.tol

        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0): # if image is too dark we return the image
            return img
        else:
            img1 = img[:,:,0][np.ix_(mask.any(1),mask.any(0))]  #for channel_1 (R)
            img2 = img[:,:,1][np.ix_(mask.any(1),mask.any(0))]  #for channel_2 (G)
            img3 = img[:,:,2][np.ix_(mask.any(1),mask.any(0))]  #for channel_3 (B)
            img = np.stack([img1,img2,img3],axis=-1)
        return img

    def Gaussian_blur(self, img, is_gaussianblur = False):

        '''This function is used for adding Gaussian blur (image smoothing technique) which helps in reducing noise in the image.'''

        img = cv2.addWeighted(img,4,cv2.GaussianBlur(img,(0,0),self.sigmaX),-4,128)
        return img

    def draw_circle(self,img, is_drawcircle = True):

        '''This function is used for drawing a circle from the center of the image.'''

        x = int(self.img_width/2)
        y = int(self.img_height/2)
        r = np.amin((x,y))     # finding radius to draw a circle from the center of the image
        circle_img = np.zeros((self.img_height, self.img_width), np.uint8)
        cv2.circle(circle_img, (x,y), int(r), 1, thickness=-1)
        img = cv2.bitwise_and(img, img, mask=circle_img)
        return img

    def image_preprocessing(self, img, is_cropping = True, is_gaussianblur = True):

        """
        This function takes an image -> crops the extra dark part, resizes, draw a circle on it, and finally adds a gaussian blur to the images
        Args : image - (numpy.ndarray) an image which we need to process
           cropping - (boolean) whether to perform cropping of extra part(True by Default) or not(False)
           gaussian_blur - (boolean) whether to apply gaussian blur to an image(True by Default) or not(False)
        Output : (numpy.ndarray) preprocessed image
        """

        if img.ndim == 2:
            img = self.cropping_2D(img, is_cropping)  #calling cropping_2D for a GRAY image
        else:
            img = self.cropping_3D(img, is_cropping)  #calling cropping_3D for a RGB image
        img = cv2.resize(img, (self.img_height, self.img_width))  # resizing the image with specified values
        # img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = self.draw_circle(img)  #calling draw_circle
        img = self.Gaussian_blur(img, is_gaussianblur) #calling Gaussian_blur
        return img

# %%
import cv2
import numpy as np
from PIL import Image


def preprocess_pil_image(input_image_pil,imgh=224,imgw=224,channels=3):
    # Convert PIL image to numpy array
    input_image_np = np.array(input_image_pil)

    # Initialize the ImageProcessing class
    img_processor = ImageProcessing(imgh,imgw,channels)

    # Perform image preprocessing using the ImageProcessing class
    preprocessed_image_np = img_processor.image_preprocessing(input_image_np)

    # Convert preprocessed numpy array back to PIL image
    preprocessed_image_pil = Image.fromarray(preprocessed_image_np)

    return preprocessed_image_pil

# %%
from PIL import Image

# Load your input PIL image
input_image_pil = Image.open("/content/hello.img")

# Preprocess the image using the function
preprocessed_image_pil = preprocess_pil_image(input_image_pil)

# You can save or display the preprocessed image as needed
preprocessed_image_pil.save("preprocessed_image.jpg")
# preprocessed_image_pil.show()

# %%
single_image_transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
img_tensor=single_image_transform(preprocessed_image_pil)

# %%
def run_inference(model,img_tensor):

# %%
img_tensor.shape
# Out:
# torch.Size([3, 224, 224])

# %%
# This cell is added by sphinx-gallery
# It can be customized to whatever you like
# %matplotlib inline

# %% [markdown]
# Quantum transfer learning {#quantum_transfer_learning}
# =========================
#
# ::: {.meta}
# :property=\"og:description\": Combine PyTorch and PennyLane to train a
# hybrid quantum-classical image classifier using transfer learning.
# :property=\"og:image\":
# <https://pennylane.ai/qml/_images/transfer_images.png>
# :::
#
# *Author: Andrea Mari --- Posted: 19 December 2019. Last updated: 28
# January 2021.*
#
# In this tutorial we apply a machine learning method, known as *transfer
# learning*, to an image classifier based on a hybrid classical-quantum
# network.
#
# This example follows the general structure of the PyTorch [tutorial on
# transfer
# learning](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)
# by Sasank Chilamkurthy, with the crucial difference of using a quantum
# circuit to perform the final classification task.
#
# More details on this topic can be found in the research paper \[1\]
# ([Mari et al. (2019)](https://arxiv.org/abs/1912.08278)).
#
# Introduction
# ------------
#
# Transfer learning is a well-established technique for training
# artificial neural networks (see e.g., Ref. \[2\]), which is based on the
# general intuition that if a pre-trained network is good at solving a
# given problem, then, with just a bit of additional training, it can be
# used to also solve a different but related problem.
#
# As discussed in Ref. \[1\], this idea can be formalized in terms of two
# abstract networks $A$ and $B$, independently from their quantum or
# classical physical nature.
#
# |
#
# ![](../demonstrations/quantum_transfer_learning/transfer_learning_general.png){.align-center}
#
# |
#
# As sketched in the above figure, one can give the following **general
# definition of the transfer learning method**:
#
# 1.  Take a network $A$ that has been pre-trained on a dataset $D_A$ and
#     for a given task $T_A$.
# 2.  Remove some of the final layers. In this way, the resulting
#     truncated network $A'$ can be used as a feature extractor.
# 3.  Connect a new trainable network $B$ at the end of the pre-trained
#     network $A'$.
# 4.  Keep the weights of $A'$ constant, and train the final block $B$
#     with a new dataset $D_B$ and/or for a new task of interest $T_B$.
#
# When dealing with hybrid systems, depending on the physical nature
# (classical or quantum) of the networks $A$ and $B$, one can have
# different implementations of transfer learning as
#
# summarized in following table:
#
# |
#
# ::: {.rst-class}
# docstable
# :::
#
#   -------------------------------------------------------------------------
#   Network A   Network B   Transfer learning scheme
#   ----------- ----------- -------------------------------------------------
#   Classical   Classical   CC - Standard classical method. See e.g., Ref.
#                           \[2\].
#
#   Classical   Quantum     CQ - **Hybrid model presented in this tutorial.**
#
#   Quantum     Classical   QC - Model studied in Ref. \[1\].
#
#   Quantum     Quantum     QQ - Model studied in Ref. \[1\].
#   -------------------------------------------------------------------------
#
# Classical-to-quantum transfer learning
# --------------------------------------
#
# We focus on the CQ transfer learning scheme discussed in the previous
# section and we give a specific example.
#
# 1.  As pre-trained network $A$ we use **ResNet18**, a deep residual
#     neural network introduced by Microsoft in Ref. \[3\], which is
#     pre-trained on the *ImageNet* dataset.
# 2.  After removing its final layer we obtain $A'$, a pre-processing
#     block which maps any input high-resolution image into 512 abstract
#     features.
# 3.  Such features are classified by a 4-qubit \"dressed quantum
#     circuit\" $B$, i.e., a variational quantum circuit sandwiched
#     between two classical layers.
# 4.  The hybrid model is trained, keeping $A'$ constant, on the
#     *Hymenoptera* dataset (a small subclass of ImageNet) containing
#     images of *ants* and *bees*.
#
# A graphical representation of the full data processing pipeline is given
# in the figure below.
#
# ![](../demonstrations/quantum_transfer_learning/transfer_learning_c2q.png){.align-center}

# %% [markdown]
# General setup
# =============
#
# ::: {.note}
# ::: {.title}
# Note
# :::
#
# To use the PyTorch interface in PennyLane, you must first [install
# PyTorch](https://pytorch.org/get-started/locally/#start-locally).
# :::
#
# In addition to *PennyLane*, we will also need some standard *PyTorch*
# libraries and the plotting library *matplotlib*.

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.31.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24 in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.10.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 28.6 MB/s eta 0:00:00
# Collecting autograd<=1.5 (from pennylane)
#   Downloading autograd-1.5-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray<=0.6.3,>=0.3.1 (from pennylane)
#   Downloading autoray-0.6.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.1)
# Collecting pennylane-lightning>=0.31 (from pennylane)
#   Downloading PennyLane_Lightning-0.31.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.7.1)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd<=1.5->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2023.7.22)
# Installing collected packages: semantic-version, rustworkx, autoray, autograd, pennylane-lightning, pennylane
#   Attempting uninstall: autograd
#     Found existing installation: autograd 1.6.2
#     Uninstalling autograd-1.6.2:
#       Successfully uninstalled autograd-1.6.2
# Successfully installed autograd-1.5 autoray-0.6.3 pennylane-0.31.1 pennylane-lightning-0.31.0 rustworkx-0.13.1 semantic-version-2.10.0

# %%
# Some parts of this code are based on the Python script:
# https://github.com/pytorch/tutorials/blob/master/beginner_source/transfer_learning_tutorial.py
# License: BSD

import time
import os
import copy

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms

# Pennylane
import pennylane as qml
from pennylane import numpy as np

torch.manual_seed(42)
np.random.seed(42)

# Plotting
import matplotlib.pyplot as plt

# OpenMP: number of parallel threads.
# os.environ["OMP_NUM_THREADS"] = "1"

# %% [markdown]
# Setting of the main hyper-parameters of the model
# =================================================
#
# ::: {.note}
# ::: {.title}
# Note
# :::
#
# To reproduce the results of Ref. \[1\], `num_epochs` should be set to
# `30` which may take a long time. We suggest to first try with
# `num_epochs=1` and, if everything runs smoothly, increase it to a larger
# value.
# :::

# %%
n_qubits = 8                # Number of qubits
step = 0.0008               # Learning rate
batch_size = 32             # Number of samples for each training step
num_epochs = 10              # Number of training epochs
q_depth = 4                 # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1    # Learning rate reduction applied every 10 epochs.
q_delta = 0.01              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer
step_size=10  # given in lr_scheduler

# %%
n_qubits = 4             # Number of qubits
step = 0.001               # Learning rate
batch_size = 32             # Number of samples for each training step
num_epochs = 10              # Number of training epochs
q_depth = 6                # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1    # Learning rate reduction applied every 10 epochs.
q_delta = 0.05              # Initial spread of random quantum weights
start_time = time.time()    # Start of the computation timer

# %% [markdown]
# We initialize a PennyLane device with a `default.qubit` backend.

# %%
dev = qml.device("lightning.qubit", wires=n_qubits)

# %% [markdown]
# We configure PyTorch to use CUDA only if available. Otherwise the CPU is
# used.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Dataset loading
# ===============
#
# ::: {.note}
# ::: {.title}
# Note
# :::
#
# The dataset containing images of *ants* and *bees* can be downloaded
# [here](https://download.pytorch.org/tutorial/hymenoptera_data.zip) and
# should be extracted in the subfolder `../_data/hymenoptera_data`.
# :::
#
# This is a very small dataset (roughly 250 images), too small for
# training from scratch a classical or quantum model, however it is enough
# when using *transfer learning* approach.
#
# The PyTorch packages `torchvision` and `torch.utils.data` are used for
# loading the dataset and performing standard preliminary image
# operations: resize, center, crop, normalize, *etc.*

# %% [markdown]
# ## Downloading our idrid dataset hosted on Roboflow

# %%
# !wget 'https://app.roboflow.com/ds/7fCe8COjHA?key=u6dgB5TFOp'
# !unzip '/content/7fCe8COjHA?key=u6dgB5TFOp' -d '/content/idrid'
# !unzip '/content/drive/MyDrive/grid 5.0 aj/idrid_all_aug.zip' -d '/content/idrid'
# Out:
# --2023-08-20 07:44:32--  https://app.roboflow.com/ds/7fCe8COjHA?key=u6dgB5TFOp
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.65.195, 151.101.1.195
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.65.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/SepQJzSnBuVTJYWpwCfV5hzkB8E2/fgX391s1QdxzbxwU4HTp/1/folder.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230820%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230820T074432Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# --2023-08-20 07:44:32--  https://storage.googleapis.com/roboflow-platform-exports/SepQJzSnBuVTJYWpwCfV5hzkB8E2/fgX391s1QdxzbxwU4HTp/1/folder.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230820%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230820T074432Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.117.128, 142.250.99.128, 142.250.107.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.117.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4858679 (4.6M) [application/zip]
# Saving to: ‘7fCe8COjHA?key=u6dgB5TFOp’
#
# 7fCe8COjHA?key=u6dg 100%[===================>]   4.63M  9.11MB/s    in 0.5s
#
# 2023-08-20 07:44:33 (9.11 MB/s) - ‘7fCe8COjHA?key=u6dgB5TFOp’ saved [4858679/4858679]
#
# Archive:  /content/7fCe8COjHA?key=u6dgB5TFOp
#  extracting: /content/idrid/README.dataset.txt
#  extracting: /content/idrid/README.roboflow.txt
#    creating: /content/idrid/test/
#    creating: /content/idrid/test/0/
#  extracting: /content/idrid/test/0/test0_0_jpg.rf.2fb48afff2f97a4a37831da2a57a5019.jpg
#  extracting: /content/idrid/test/0/test0_10_jpg.rf.60f370e422257cb5345c901e53e2bf8e.jpg
#  extracting: /content/idrid/test/0/test0_11_jpg.rf.9aeec3a70e22b17b616bb4072e59728e.jpg
#  extracting: /content/idrid/test/0/test0_12_jpg.rf.d7f1fa2117eeadeac9833ea566cfc618.jpg
#  extracting: /content/idrid/test/0/test0_13_jpg.rf.3c2618c95849cc22d14f4c0ef50397ac.jpg
#  extracting: /content/idrid/test/0/test0_14_jpg.rf.6de12f7c46f64c87a04b9c05de6e8a48.jpg
#  extracting: /content/idrid/test/0/test0_15_jpg.rf.a60de342381de3d172808dda8b8cacbc.jpg
#  extracting: /content/idrid/test/0/test0_16_jpg.rf.3ce577ee85b54fabcbc5c7fe7e20e7db.jpg
#  extracting: /content/idrid/test/0/test0_17_jpg.rf.3a397e1d14f018577ca5f428a3527e51.jpg
#  extracting: /content/idrid/test/0/test0_18_jpg.rf.ca1e74b8be18e8e9af9443d1c175267c.jpg
#  extracting: /content/idrid/test/0/test0_19_jpg.rf.69a4f3c8688827268cd88efd74d32f09.jpg
#  extracting: /content/idrid/test/0/test0_1_jpg.rf.a4865fd0d8cf54abac642ef20cc767cd.jpg
#  extracting: /content/idrid/test/0/test0_20_jpg.rf.9f3aca06e56209984bf8f2e8ecfdf549.jpg
#  extracting: /content/idrid/test/0/test0_21_jpg.rf.ef5a1f4f5e60616e8e8dd276fecd8d3a.jpg
#  extracting: /content/idrid/test/0/test0_22_jpg.rf.d03016096ea46be9f4009c2cc019cd7d.jpg
#  extracting: /content/idrid/test/0/test0_23_jpg.rf.0ea59e0d1328022edd07f83052e85044.jpg
#  extracting: /content/idrid/test/0/test0_24_jpg.rf.af73b8c8f4088d87632c6737cdf52719.jpg
#  extracting: /content/idrid/test/0/test0_25_jpg.rf.ebe79f04e1ee37e21aa6596c5d33fa99.jpg
#  extracting: /content/idrid/test/0/test0_26_jpg.rf.aa31c14d274f4c21c4eb660b40f1ea63.jpg
#  extracting: /content/idrid/test/0/test0_27_jpg.rf.6a7ca558709cebdc898e552e52b53877.jpg
#  extracting: /content/idrid/test/0/test0_28_jpg.rf.25387be14d8daefd14c62ed6a3a99908.jpg
#  extracting: /content/idrid/test/0/test0_29_jpg.rf.46b7185b37853165ca8481a0f4ec2595.jpg
#  extracting: /content/idrid/test/0/test0_2_jpg.rf.00adb9413e7dadc9456a434585ed568d.jpg
#  extracting: /content/idrid/test/0/test0_30_jpg.rf.da19432473a42851691a5e70b5d4cbef.jpg
#  extracting: /content/idrid/test/0/test0_31_jpg.rf.6e7df23e6ef429a0ac5e41f8a59f0c4b.jpg
#  extracting: /content/idrid/test/0/test0_32_jpg.rf.9385f2c59a72af08d9df0696c13f5194.jpg
#  extracting: /content/idrid/test/0/test0_33_jpg.rf.796644664c3767fe5eeb8afdaf3e39a0.jpg
#  extracting: /content/idrid/test/0/test0_3_jpg.rf.f177010a9c0f36f789bd9f38ca27a9f0.jpg
#  extracting: /content/idrid/test/0/test0_4_jpg.rf.5a5e257304c0807ceeb059a2b3057b33.jpg
#  extracting: /content/idrid/test/0/test0_5_jpg.rf.39a003d6d4b746def6070900c236e71f.jpg
#  extracting: /content/idrid/test/0/test0_6_jpg.rf.7d357ba6dfd8f62635d4ecb09210e784.jpg
#  extracting: /content/idrid/test/0/test0_7_jpg.rf.158651548f9c3beb0e42147d4b6c08ca.jpg
#  extracting: /content/idrid/test/0/test0_8_jpg.rf.c594dafe274af86be0a9128f3c90de3a.jpg
#  extracting: /content/idrid/test/0/test0_9_jpg.rf.ad807c7f4588a9a54450e4b99247f881.jpg
#    creating: /content/idrid/test/1/
#  extracting: /content/idrid/test/1/test0_0_jpg.rf.9a26f145de4efbbbe263bc4739025dac.jpg
#  extracting: /content/idrid/test/1/test0_10_jpg.rf.75fd318035ad3b8f2c1f44d93abbdd1e.jpg
#  extracting: /content/idrid/test/1/test0_11_jpg.rf.209271dcce570e276c05eb0b5fdf8c94.jpg
#  extracting: /content/idrid/test/1/test0_12_jpg.rf.57773834bebb51ad10c774a5e9fc854d.jpg
#  extracting: /content/idrid/test/1/test0_13_jpg.rf.84831e70cb213a2bbd5e368c8927eef3.jpg
#  extracting: /content/idrid/test/1/test0_14_jpg.rf.9b9e4e13d1cebec5b513c7ab2a67c90b.jpg
#  extracting: /content/idrid/test/1/test0_15_jpg.rf.9b470f7dc342ad5ac10d7ba02b966c22.jpg
#  extracting: /content/idrid/test/1/test0_16_jpg.rf.ecb4e11eafb7c53b50d879cbfab391be.jpg
#  extracting: /content/idrid/test/1/test0_17_jpg.rf.e6e6db84e82987d1d1862f36a6925ee4.jpg
#  extracting: /content/idrid/test/1/test0_18_jpg.rf.3929fd8871b7ca6ea3f2bc04f67c38d3.jpg
#  extracting: /content/idrid/test/1/test0_1_jpg.rf.e80aebed255b6622b940a5fcc1eca17d.jpg
#  extracting: /content/idrid/test/1/test0_2_jpg.rf.6a526a3c310bbc5372c927ff4685e449.jpg
#  extracting: /content/idrid/test/1/test0_3_jpg.rf.5705479fdb2b9f22cc3b5d1d013ed966.jpg
#  extracting: /content/idrid/test/1/test0_4_jpg.rf.9d36890d471eae14f6d77db414f407f5.jpg
#  extracting: /content/idrid/test/1/test0_5_jpg.rf.7302a2f0e18d8a962a065a0bd895799f.jpg
#  extracting: /content/idrid/test/1/test0_6_jpg.rf.6f2cb375826ff88c6d9c5626f3c8a88b.jpg
#  extracting: /content/idrid/test/1/test0_7_jpg.rf.134a675953813170a287e2d417710411.jpg
#  extracting: /content/idrid/test/1/test0_8_jpg.rf.dc0f3f4ff656ab6c31ab27250e0eea85.jpg
#  extracting: /content/idrid/test/1/test0_9_jpg.rf.0076c44efe48cae1965cb95602d4718d.jpg
#    creating: /content/idrid/test/2/
#  extracting: /content/idrid/test/2/test1_0_jpg.rf.d80e814da7adfee7ccc2f5b3f685fd9c.jpg
#  extracting: /content/idrid/test/2/test1_10_jpg.rf.10421fe2bb7a1872512934aa12d4f9c9.jpg
#  extracting: /content/idrid/test/2/test1_11_jpg.rf.4ca8e46bd511cb8bf90c4ca0035c5787.jpg
#  extracting: /content/idrid/test/2/test1_12_jpg.rf.2a330fe4e00d04597678de29f37c90be.jpg
#  extracting: /content/idrid/test/2/test1_1_jpg.rf.f2f92856c1df837b1136f972d348d1e0.jpg
#  extracting: /content/idrid/test/2/test1_2_jpg.rf.56f8088468945bff124da5a9e25140e3.jpg
#  extracting: /content/idrid/test/2/test1_3_jpg.rf.80512962c3a9a2360b43c0eb7b98d83b.jpg
#  extracting: /content/idrid/test/2/test1_4_jpg.rf.a96190e985b997777ae9cfc3645633f1.jpg
#  extracting: /content/idrid/test/2/test1_5_jpg.rf.7274cafb12f5a22776bad09c535d460f.jpg
#  extracting: /content/idrid/test/2/test1_6_jpg.rf.9e0ab27c55ffb5b4313b995898ec2e7c.jpg
#  extracting: /content/idrid/test/2/test1_7_jpg.rf.a7032db5d943fda6703e8142a6e3fefe.jpg
#  extracting: /content/idrid/test/2/test1_8_jpg.rf.70438875aa336738d440d117df5c3c02.jpg
#  extracting: /content/idrid/test/2/test1_9_jpg.rf.7e139f224ff2a255418d98354bd4ff97.jpg
#    creating: /content/idrid/train/
#    creating: /content/idrid/train/0/
#  extracting: /content/idrid/train/0/train0_0_jpg.rf.6d99813dab41e87b4fd2eaf7cd576d88.jpg
#  extracting: /content/idrid/train/0/train0_100_jpg.rf.99d412cbd540948a1d0b37122dd4b88a.jpg
#  extracting: /content/idrid/train/0/train0_101_jpg.rf.c0ba8e01ca47b043c2e592b2f88b5bda.jpg
#  extracting: /content/idrid/train/0/train0_102_jpg.rf.33514846b099a112d15fddc2ce7e73fe.jpg
#  extracting: /content/idrid/train/0/train0_103_jpg.rf.ac30ebf8ade2c7dfc4e63178a23646ad.jpg
#  extracting: /content/idrid/train/0/train0_104_jpg.rf.c2735312f493e1b45f2cfaf69f8ecd85.jpg
#  extracting: /content/idrid/train/0/train0_105_jpg.rf.93524eae70e26954910320ebb85dfd43.jpg
#  extracting: /content/idrid/train/0/train0_106_jpg.rf.0132acebfaa5913cd3e4adfaeca3d297.jpg
#  extracting: /content/idrid/train/0/train0_107_jpg.rf.fd895494d28875894b938117812fbf7a.jpg
#  extracting: /content/idrid/train/0/train0_108_jpg.rf.d6780572d3a696e68092094514175e48.jpg
#  extracting: /content/idrid/train/0/train0_109_jpg.rf.15b65f0687527e597d82e64c81d9484b.jpg
#  extracting: /content/idrid/train/0/train0_10_jpg.rf.22f9b37c6f0d4ccc29ac088789dad099.jpg
#  extracting: /content/idrid/train/0/train0_110_jpg.rf.18057136f77dee23980288d5367d6fe8.jpg
#  extracting: /content/idrid/train/0/train0_111_jpg.rf.7215255c76bc08331775bc955962890a.jpg
#  extracting: /content/idrid/train/0/train0_112_jpg.rf.586d406d5061556beb002674b45c8bb2.jpg
#  extracting: /content/idrid/train/0/train0_113_jpg.rf.057371b33cf747b0a9e23ecad1aae2eb.jpg
#  extracting: /content/idrid/train/0/train0_114_jpg.rf.a4b5adffeeef0559e52cf6c0dded20ed.jpg
#  extracting: /content/idrid/train/0/train0_115_jpg.rf.c38dd12be44e8c25924d7a135dda6365.jpg
#  extracting: /content/idrid/train/0/train0_116_jpg.rf.9f93dc2a995c2f2b6493085d57e3cbdc.jpg
#  extracting: /content/idrid/train/0/train0_117_jpg.rf.e581e91f28ba1d57f6e3181e0baa208d.jpg
#  extracting: /content/idrid/train/0/train0_118_jpg.rf.039ea1f0ebe0c67b58e2cf7393d4f14b.jpg
#  extracting: /content/idrid/train/0/train0_119_jpg.rf.873e781d614fa0431190678bec6eb749.jpg
#  extracting: /content/idrid/train/0/train0_11_jpg.rf.88766a83fd3cdb4bdaf8700826f0fb77.jpg
#  extracting: /content/idrid/train/0/train0_120_jpg.rf.9bdfa4d28b4f4c43817181de09ffe6b1.jpg
#  extracting: /content/idrid/train/0/train0_121_jpg.rf.fb3e5cb3f1e7570bcf2420c01c7def71.jpg
#  extracting: /content/idrid/train/0/train0_122_jpg.rf.b8097aef313bd84457b646f51a8a3434.jpg
#  extracting: /content/idrid/train/0/train0_123_jpg.rf.d1f6689b944b030f5421c6652bd0b9b6.jpg
#  extracting: /content/idrid/train/0/train0_124_jpg.rf.3d7825fa7608f775ffcb2e48ee4dc29c.jpg
#  extracting: /content/idrid/train/0/train0_125_jpg.rf.8562797851784d450bc2cfbc62789613.jpg
#  extracting: /content/idrid/train/0/train0_126_jpg.rf.62d88fa861d295cbd044c4657752fd09.jpg
#  extracting: /content/idrid/train/0/train0_127_jpg.rf.0ed17c3573ef11cb473cc874247e6d65.jpg
#  extracting: /content/idrid/train/0/train0_128_jpg.rf.a22d64b49b913208e39154e027fb6a63.jpg
#  extracting: /content/idrid/train/0/train0_129_jpg.rf.1bbaa0df2eefc4e56a0d229038dab111.jpg
#  extracting: /content/idrid/train/0/train0_12_jpg.rf.4c750a0dc10d5701717abc038a280957.jpg
#  extracting: /content/idrid/train/0/train0_130_jpg.rf.50635dc6a368a3880905d260cef9da7a.jpg
#  extracting: /content/idrid/train/0/train0_131_jpg.rf.db9e5270dc5951a12bd15a75d83f8fd3.jpg
#  extracting: /content/idrid/train/0/train0_132_jpg.rf.c5ece0e962901c0a899420848c53445b.jpg
#  extracting: /content/idrid/train/0/train0_13_jpg.rf.a26cb6cc725073f6b721dad7a27c632e.jpg
#  extracting: /content/idrid/train/0/train0_14_jpg.rf.2ae700a9c639d7fcbcd22285de71e225.jpg
#  extracting: /content/idrid/train/0/train0_15_jpg.rf.dfb7a3678b88f9316fcc666dfa8eb718.jpg
#  extracting: /content/idrid/train/0/train0_16_jpg.rf.ad7251aa94db34c3993313d0a413fcb2.jpg
#  extracting: /content/idrid/train/0/train0_17_jpg.rf.4c52336de96a0c553d204530e671efef.jpg
#  extracting: /content/idrid/train/0/train0_18_jpg.rf.020dd116fbffccb3a33562b21b1ccc1c.jpg
#  extracting: /content/idrid/train/0/train0_19_jpg.rf.fc56610eed9d20dcf227bb169e30e6ef.jpg
#  extracting: /content/idrid/train/0/train0_1_jpg.rf.a15c0737aa88b6862913462e7c02cec3.jpg
#  extracting: /content/idrid/train/0/train0_20_jpg.rf.eba462589633c95e28829f16a9943b6b.jpg
#  extracting: /content/idrid/train/0/train0_21_jpg.rf.afabee0163458afba4a1e4a06fc50606.jpg
#  extracting: /content/idrid/train/0/train0_22_jpg.rf.5f2c53dee96db2f826f86e4f108d9484.jpg
#  extracting: /content/idrid/train/0/train0_23_jpg.rf.b61b6f161c80b7b77f8570fa0764eb8b.jpg
#  extracting: /content/idrid/train/0/train0_24_jpg.rf.4f16001d5dcb165a0eedad9fc60056c2.jpg
#  extracting: /content/idrid/train/0/train0_25_jpg.rf.7e9d47b0492b76c3c6fee069f875245d.jpg
#  extracting: /content/idrid/train/0/train0_26_jpg.rf.c8a33b230105d305b04a284eabd9fd09.jpg
#  extracting: /content/idrid/train/0/train0_27_jpg.rf.9535205656774e0c36aa1b6918113d64.jpg
#  extracting: /content/idrid/train/0/train0_28_jpg.rf.ecd8c7d9fb41ebdcd0e8226fdad0f25f.jpg
#  extracting: /content/idrid/train/0/train0_29_jpg.rf.95920802140d9ca67c0e544fb515d852.jpg
#  extracting: /content/idrid/train/0/train0_2_jpg.rf.07c5d4e04e4c883dc626c2b881acc663.jpg
#  extracting: /content/idrid/train/0/train0_30_jpg.rf.a46832370807cf7131416fa6e94c3490.jpg
#  extracting: /content/idrid/train/0/train0_31_jpg.rf.644bfa352e7de42085e734d39315551e.jpg
#  extracting: /content/idrid/train/0/train0_32_jpg.rf.b15d6f04906a981995e3d0196250e1fc.jpg
#  extracting: /content/idrid/train/0/train0_33_jpg.rf.eecdfd6205a0540e232a10483475a67d.jpg
#  extracting: /content/idrid/train/0/train0_34_jpg.rf.a3da39efe67a477be1092682abd366c7.jpg
#  extracting: /content/idrid/train/0/train0_35_jpg.rf.06f7e9f779332c848f0f2a4582c6e14f.jpg
#  extracting: /content/idrid/train/0/train0_36_jpg.rf.d0f7334d220de9016ee4c4d04ebda32c.jpg
#  extracting: /content/idrid/train/0/train0_37_jpg.rf.8cb7ce639b2fd58c1599373e262f1678.jpg
#  extracting: /content/idrid/train/0/train0_38_jpg.rf.b3cc090bd9d947b9ded7815ce8b6f317.jpg
#  extracting: /content/idrid/train/0/train0_39_jpg.rf.d416af2313468c904c7225efaa9001b4.jpg
#  extracting: /content/idrid/train/0/train0_3_jpg.rf.3592ab92a65b7c478152494c79dbda90.jpg
#  extracting: /content/idrid/train/0/train0_40_jpg.rf.deedfd7bd696bc35ca5b4257fc7efe2c.jpg
#  extracting: /content/idrid/train/0/train0_41_jpg.rf.087818c5853f86deab4394c172eecb67.jpg
#  extracting: /content/idrid/train/0/train0_42_jpg.rf.b74ab28b4bbea7cb2fd6be5ed1e415ec.jpg
#  extracting: /content/idrid/train/0/train0_43_jpg.rf.1244e8695f25e5f605f64ae0af48a9a2.jpg
#  extracting: /content/idrid/train/0/train0_44_jpg.rf.0403428f56e85e79763debe2f8c1698e.jpg
#  extracting: /content/idrid/train/0/train0_45_jpg.rf.1f3a03aa26d2e2465a8a911f4c2dc75f.jpg
#  extracting: /content/idrid/train/0/train0_46_jpg.rf.dbadc68e5269530bbaf842a727bdd277.jpg
#  extracting: /content/idrid/train/0/train0_47_jpg.rf.4f60d737531531a3ba52cf9ecfa9a10c.jpg
#  extracting: /content/idrid/train/0/train0_48_jpg.rf.c2508d14830da6aed2ae77da3da51034.jpg
#  extracting: /content/idrid/train/0/train0_49_jpg.rf.d0735b15a14896313526361fe975275c.jpg
#  extracting: /content/idrid/train/0/train0_4_jpg.rf.f5ed08fa668eec3d1dfc4ff978318855.jpg
#  extracting: /content/idrid/train/0/train0_50_jpg.rf.5edacd6632fcfa51736ceb92e0104c58.jpg
#  extracting: /content/idrid/train/0/train0_51_jpg.rf.25444a24a7905107cbd57b07adfd03aa.jpg
#  extracting: /content/idrid/train/0/train0_52_jpg.rf.db5923afdea6e2f9bb6e29970c0f5ab6.jpg
#  extracting: /content/idrid/train/0/train0_53_jpg.rf.6b5f112dc99f0a131da3cb61a220129c.jpg
#  extracting: /content/idrid/train/0/train0_54_jpg.rf.4bc9e1726b4be11717ea5d9e5d670c7f.jpg
#  extracting: /content/idrid/train/0/train0_55_jpg.rf.a650e1e847670270861668f742732172.jpg
#  extracting: /content/idrid/train/0/train0_56_jpg.rf.8523301528a83c441d1821e0e9d57013.jpg
#  extracting: /content/idrid/train/0/train0_57_jpg.rf.adf57597390ba936107e86aea3b61f8f.jpg
#  extracting: /content/idrid/train/0/train0_58_jpg.rf.02dd93b7a31ac3ce36308d0555ed0fb2.jpg
#  extracting: /content/idrid/train/0/train0_59_jpg.rf.6b591595fff9190d4829130ed8dd4278.jpg
#  extracting: /content/idrid/train/0/train0_5_jpg.rf.3c8381df309c28896d91740e77341405.jpg
#  extracting: /content/idrid/train/0/train0_60_jpg.rf.ab0d344c02a090540fd6c2c05326def6.jpg
#  extracting: /content/idrid/train/0/train0_61_jpg.rf.579639fb5aef7cbb47930718b878d2aa.jpg
#  extracting: /content/idrid/train/0/train0_62_jpg.rf.cfd82125c3bfccb262f25b6c7ff20a4c.jpg
#  extracting: /content/idrid/train/0/train0_63_jpg.rf.67e7337a9cedad2d9aa2bd3d1268e556.jpg
#  extracting: /content/idrid/train/0/train0_64_jpg.rf.ed2759bc2af98283eba7ddb5bb2aff8d.jpg
#  extracting: /content/idrid/train/0/train0_65_jpg.rf.73e63b90f657460d718ba95cc9082cfc.jpg
#  extracting: /content/idrid/train/0/train0_66_jpg.rf.c836eb4e8adde78fbc382a504307f0eb.jpg
#  extracting: /content/idrid/train/0/train0_67_jpg.rf.43952a4c8eadc9e17562f2173f144cfb.jpg
#  extracting: /content/idrid/train/0/train0_68_jpg.rf.2026af2cc79d37e80b31271956f8c5c3.jpg
#  extracting: /content/idrid/train/0/train0_69_jpg.rf.c40238bc66c96c2256d4037fac9172fa.jpg
#  extracting: /content/idrid/train/0/train0_6_jpg.rf.e47b6206cb72a63802209d03e05ef550.jpg
#  extracting: /content/idrid/train/0/train0_70_jpg.rf.f6ba5eb8a141d03e60f1d00f7cac405d.jpg
#  extracting: /content/idrid/train/0/train0_71_jpg.rf.859fba98fe1c38aed94a3ce68ec0f549.jpg
#  extracting: /content/idrid/train/0/train0_72_jpg.rf.d5db5c5c2bab339aaf82912866dbe2e9.jpg
#  extracting: /content/idrid/train/0/train0_73_jpg.rf.77e96b582a6996d8979aca899cf0ddde.jpg
#  extracting: /content/idrid/train/0/train0_74_jpg.rf.21fe293444cb1462e5a9926746d579b3.jpg
#  extracting: /content/idrid/train/0/train0_75_jpg.rf.3b8eaae5ee39e6d347057f196dfcf073.jpg
#  extracting: /content/idrid/train/0/train0_76_jpg.rf.568f5c205a62e2d27dd61aaa9129ff5a.jpg
#  extracting: /content/idrid/train/0/train0_77_jpg.rf.ba9ba513c133c9ae94691d045a45ce01.jpg
#  extracting: /content/idrid/train/0/train0_78_jpg.rf.b9100f009fa8e77e6ea6962e0acf17ba.jpg
#  extracting: /content/idrid/train/0/train0_79_jpg.rf.371b5f4009c04ca8f5c6749f996f845b.jpg
#  extracting: /content/idrid/train/0/train0_7_jpg.rf.460e6e8d4eabf1439d411fe60f243691.jpg
#  extracting: /content/idrid/train/0/train0_80_jpg.rf.80fb05c4a1e45906b612bdc95194c216.jpg
#  extracting: /content/idrid/train/0/train0_81_jpg.rf.8ef156e76a217f2e1600e79d2ccbaf61.jpg
#  extracting: /content/idrid/train/0/train0_82_jpg.rf.d7fa95198a6f44424615e01ebed60bed.jpg
#  extracting: /content/idrid/train/0/train0_83_jpg.rf.a0e8d721f3ee526e1580014d3d8a5ce3.jpg
#  extracting: /content/idrid/train/0/train0_84_jpg.rf.58fcb68c35f72063b77e3ad5e3183128.jpg
#  extracting: /content/idrid/train/0/train0_85_jpg.rf.869df7435c1de518519c01d58873f0a8.jpg
#  extracting: /content/idrid/train/0/train0_86_jpg.rf.dbc2e02454b208665ed1a46f3c845fcf.jpg
#  extracting: /content/idrid/train/0/train0_87_jpg.rf.ce4d0d8f0b634d6b68342361979b05b7.jpg
#  extracting: /content/idrid/train/0/train0_88_jpg.rf.c87bc42c52c2750d02fe0ed6886e93ab.jpg
#  extracting: /content/idrid/train/0/train0_89_jpg.rf.d6afce000e5a3e8cc989f3655b783876.jpg
#  extracting: /content/idrid/train/0/train0_8_jpg.rf.a3967b18f38fa7bd013625b2e23d7361.jpg
#  extracting: /content/idrid/train/0/train0_90_jpg.rf.0333044c3316c65c816c2c2f94de5056.jpg
#  extracting: /content/idrid/train/0/train0_91_jpg.rf.0cdcc402fcc5366a13c9ec39e5be94e8.jpg
#  extracting: /content/idrid/train/0/train0_92_jpg.rf.b7beab20b53419ac679d791aece6b743.jpg
#  extracting: /content/idrid/train/0/train0_93_jpg.rf.826a9a2a527afd52fe5792b08f3e162f.jpg
#  extracting: /content/idrid/train/0/train0_94_jpg.rf.ee75aef34d7701b01b5ba4b78d8f4f4d.jpg
#  extracting: /content/idrid/train/0/train0_95_jpg.rf.70574a5c415b19aad84155a36c657128.jpg
#  extracting: /content/idrid/train/0/train0_96_jpg.rf.fd42f3eddb1a6a6143076e10ce579e5a.jpg
#  extracting: /content/idrid/train/0/train0_97_jpg.rf.fbb93504b97f1e5a2eb6b79fe0246f24.jpg
#  extracting: /content/idrid/train/0/train0_98_jpg.rf.a505f197bd43c01ece2d1a8c32649fcf.jpg
#  extracting: /content/idrid/train/0/train0_99_jpg.rf.4393ab76e5d70b50c5eb459a31b712e3.jpg
#  extracting: /content/idrid/train/0/train0_9_jpg.rf.6fc04e4fcc3335b893b7d196bdd69f21.jpg
#    creating: /content/idrid/train/1/
#  extracting: /content/idrid/train/1/train0_0_jpg.rf.8d5176325dba3267bcbe3387d814e56d.jpg
#  extracting: /content/idrid/train/1/train0_10_jpg.rf.aed1134ca3a4ff07f93abaf1453ef0b9.jpg
#  extracting: /content/idrid/train/1/train0_11_jpg.rf.a4fc2e43d3737c9529ba3046d011cdde.jpg
#  extracting: /content/idrid/train/1/train0_12_jpg.rf.ce73bf36b69f78ab058e8406c03ac5a5.jpg
#  extracting: /content/idrid/train/1/train0_13_jpg.rf.7e59dd36b9ced864f6b922c1c2a98f1c.jpg
#  extracting: /content/idrid/train/1/train0_14_jpg.rf.1089060504acd8a5fd55c60b14dc05be.jpg
#  extracting: /content/idrid/train/1/train0_15_jpg.rf.745061cca4b9f970f0f0804435c5957d.jpg
#  extracting: /content/idrid/train/1/train0_16_jpg.rf.a38a2a9adeb6f78db5ca24f64c4e815b.jpg
#  extracting: /content/idrid/train/1/train0_17_jpg.rf.62cda0fa245090c54c2ea44e3fdf22f1.jpg
#  extracting: /content/idrid/train/1/train0_18_jpg.rf.f621b0b7bdbb62ade9c659912de93b54.jpg
#  extracting: /content/idrid/train/1/train0_19_jpg.rf.2b2860016f2b6e6e30121b886ce77ded.jpg
#  extracting: /content/idrid/train/1/train0_1_jpg.rf.b3f3b62bfe8fe94c305fb6968570ccd1.jpg
#  extracting: /content/idrid/train/1/train0_20_jpg.rf.e6d987482b7ea9b9efc1bc1c59042147.jpg
#  extracting: /content/idrid/train/1/train0_21_jpg.rf.919b041d74031e14bd6ace7d5284f1d3.jpg
#  extracting: /content/idrid/train/1/train0_22_jpg.rf.3fb194a5360eb60bb121f2566aa127f2.jpg
#  extracting: /content/idrid/train/1/train0_23_jpg.rf.6fbb8e18ad69be45558be6fa354fa076.jpg
#  extracting: /content/idrid/train/1/train0_24_jpg.rf.3621f9a10f0f1f9f2b627da4d17bc624.jpg
#  extracting: /content/idrid/train/1/train0_25_jpg.rf.cdb06dd7efe8c60afc2bba7cf40c8162.jpg
#  extracting: /content/idrid/train/1/train0_26_jpg.rf.e1b922ff01bd187c5d6ed410019a1512.jpg
#  extracting: /content/idrid/train/1/train0_27_jpg.rf.d95bcbcc9f17e492daa66df0a7503935.jpg
#  extracting: /content/idrid/train/1/train0_28_jpg.rf.dd13586c89fb9e5a0374969325a4065c.jpg
#  extracting: /content/idrid/train/1/train0_29_jpg.rf.5035799db83d9fe6e2a1127e5bfeb2da.jpg
#  extracting: /content/idrid/train/1/train0_2_jpg.rf.f06eed72592ecc8ce3b23a7f1513fbd1.jpg
#  extracting: /content/idrid/train/1/train0_30_jpg.rf.a7fd5cd9aa616aac48e4a53654426dd8.jpg
#  extracting: /content/idrid/train/1/train0_31_jpg.rf.be1e9536ca22f03fbddad498b6715f06.jpg
#  extracting: /content/idrid/train/1/train0_32_jpg.rf.48e289f1085047bdc96fe636b98fc906.jpg
#  extracting: /content/idrid/train/1/train0_33_jpg.rf.284f6ca1199b80c1e6e43f82c9c2c4ca.jpg
#  extracting: /content/idrid/train/1/train0_34_jpg.rf.7785c4aea4c493b07549ce6eb6166852.jpg
#  extracting: /content/idrid/train/1/train0_35_jpg.rf.908b4583936ba14d46973b383db0c749.jpg
#  extracting: /content/idrid/train/1/train0_36_jpg.rf.807460ed5f232a3c922b7ad109ffd933.jpg
#  extracting: /content/idrid/train/1/train0_37_jpg.rf.7cb79cccb9f718838bbe7d4a45f35087.jpg
#  extracting: /content/idrid/train/1/train0_38_jpg.rf.57cbfe92fa01d46b8ce1fdcbbf2bc570.jpg
#  extracting: /content/idrid/train/1/train0_39_jpg.rf.99483915cfaf0a07353f1e7b53327cd3.jpg
#  extracting: /content/idrid/train/1/train0_3_jpg.rf.99802f37c7d24bfcadf44448daaed048.jpg
#  extracting: /content/idrid/train/1/train0_40_jpg.rf.9fbc08cc9130d6069befc0cb2d723e2a.jpg
#  extracting: /content/idrid/train/1/train0_41_jpg.rf.d64751ce00906345f7705a6796d0e0ee.jpg
#  extracting: /content/idrid/train/1/train0_42_jpg.rf.4180c85ae87352999502ae6e5c15c525.jpg
#  extracting: /content/idrid/train/1/train0_43_jpg.rf.ceac135db72e9746d999f6b29a2de745.jpg
#  extracting: /content/idrid/train/1/train0_44_jpg.rf.a6ff0ba0c817822a05508c617edf7553.jpg
#  extracting: /content/idrid/train/1/train0_45_jpg.rf.76d8c1d5d40bb4747dc147e373fe3f70.jpg
#  extracting: /content/idrid/train/1/train0_46_jpg.rf.859ce1b3545c7ece5336cb9088743e8f.jpg
#  extracting: /content/idrid/train/1/train0_47_jpg.rf.38a5f11a789eb26d888bf4f2542f0958.jpg
#  extracting: /content/idrid/train/1/train0_48_jpg.rf.57329a41a167a5fded03d54c2e39991e.jpg
#  extracting: /content/idrid/train/1/train0_49_jpg.rf.b1f83bd88b383032a29f10c28bca0001.jpg
#  extracting: /content/idrid/train/1/train0_4_jpg.rf.5e37e157f4cd5d3caee8ed2dc91c5c5e.jpg
#  extracting: /content/idrid/train/1/train0_50_jpg.rf.642ff417f5a10415ba5d6cc700e9c26e.jpg
#  extracting: /content/idrid/train/1/train0_51_jpg.rf.5db4599c754ed6bd6922fa700d9d2ddc.jpg
#  extracting: /content/idrid/train/1/train0_52_jpg.rf.0887c50dfa5326f59455bfc8b16ad3b0.jpg
#  extracting: /content/idrid/train/1/train0_53_jpg.rf.12e8aa7caeb49e62235de4f5a461a4d9.jpg
#  extracting: /content/idrid/train/1/train0_54_jpg.rf.9c044070098a3b43f706409871f7961b.jpg
#  extracting: /content/idrid/train/1/train0_55_jpg.rf.fc9ab693409b2a487eacefb0693db749.jpg
#  extracting: /content/idrid/train/1/train0_56_jpg.rf.0b43ca78779156086e85a7f8062fe2a7.jpg
#  extracting: /content/idrid/train/1/train0_57_jpg.rf.658a901c85ad4ed263d58cc734e88793.jpg
#  extracting: /content/idrid/train/1/train0_58_jpg.rf.f2e2cc5be351e3437467f8d4c928cfaa.jpg
#  extracting: /content/idrid/train/1/train0_59_jpg.rf.bb91186bf98358072c35f8634355e788.jpg
#  extracting: /content/idrid/train/1/train0_5_jpg.rf.79d709b145b6eb89bdb86612fe2fa57c.jpg
#  extracting: /content/idrid/train/1/train0_60_jpg.rf.9af01043b0685a0dca8d630c972c6905.jpg
#  extracting: /content/idrid/train/1/train0_61_jpg.rf.dc8fb58bfe996d62231fe0bf82e4e30e.jpg
#  extracting: /content/idrid/train/1/train0_62_jpg.rf.d70469240d08b31502e4f4a0e5b9d8c4.jpg
#  extracting: /content/idrid/train/1/train0_63_jpg.rf.c1e2ece8828fbdf7b754ab028694dac9.jpg
#  extracting: /content/idrid/train/1/train0_64_jpg.rf.16d527e367352007cf28d0cf05285ee5.jpg
#  extracting: /content/idrid/train/1/train0_65_jpg.rf.2e44ab9cdb8264ce931f97e3757771ad.jpg
#  extracting: /content/idrid/train/1/train0_66_jpg.rf.a2a02d7cb3b864db8cfaf1103df400a8.jpg
#  extracting: /content/idrid/train/1/train0_67_jpg.rf.c4ac83490afec07aeaf69c304c0f662c.jpg
#  extracting: /content/idrid/train/1/train0_68_jpg.rf.716d5ab60972415496dd5e81a199d657.jpg
#  extracting: /content/idrid/train/1/train0_69_jpg.rf.a1fe0ba4654022aa431dc495351bf59c.jpg
#  extracting: /content/idrid/train/1/train0_6_jpg.rf.4b037aaa459eb69a3b153c3e22b2cec6.jpg
#  extracting: /content/idrid/train/1/train0_70_jpg.rf.1e3c25700c9f33a593b196801b6849e3.jpg
#  extracting: /content/idrid/train/1/train0_71_jpg.rf.774c027e7c955d0f4fee8d8787349e1d.jpg
#  extracting: /content/idrid/train/1/train0_72_jpg.rf.77886bb9e9b309ab269b807fc808c58e.jpg
#  extracting: /content/idrid/train/1/train0_73_jpg.rf.97271d363598e0b1317ae41806c0736d.jpg
#  extracting: /content/idrid/train/1/train0_7_jpg.rf.70bc347cc11cfc04ad111342a57f31dc.jpg
#  extracting: /content/idrid/train/1/train0_8_jpg.rf.48bb5781a42047045db2e23f88ad47fb.jpg
#  extracting: /content/idrid/train/1/train0_9_jpg.rf.721d107d2f332571be0fec71c124ed25.jpg
#    creating: /content/idrid/train/2/
#  extracting: /content/idrid/train/2/train1_0_jpg.rf.d5e6a9812156fa932b3aec0952c074a9.jpg
#  extracting: /content/idrid/train/2/train1_10_jpg.rf.cf209a40273f20235e88940b8d3d1313.jpg
#  extracting: /content/idrid/train/2/train1_11_jpg.rf.d3ac2a3a670d4c34fa6c962796f26fac.jpg
#  extracting: /content/idrid/train/2/train1_12_jpg.rf.83e766353f7d9c64268c577f986b6f5d.jpg
#  extracting: /content/idrid/train/2/train1_13_jpg.rf.cb990fea12ab1fd0892a180ad70042a4.jpg
#  extracting: /content/idrid/train/2/train1_14_jpg.rf.7784e81c7b0ff2c82786b6fa838a7d47.jpg
#  extracting: /content/idrid/train/2/train1_15_jpg.rf.f3a02782ca97dc5b020e40695b0ec941.jpg
#  extracting: /content/idrid/train/2/train1_16_jpg.rf.ebe49dd3f1e66e2abb6a201613ca5382.jpg
#  extracting: /content/idrid/train/2/train1_17_jpg.rf.b0f7c0ce8f2e3b1702896dbd7921abed.jpg
#  extracting: /content/idrid/train/2/train1_18_jpg.rf.c5f4ff1013d0ded608c14a553b15dcb8.jpg
#  extracting: /content/idrid/train/2/train1_19_jpg.rf.e6cefeb0c93c5d79f9c696c6c78e88c0.jpg
#  extracting: /content/idrid/train/2/train1_1_jpg.rf.cc98d46576430af766d8aba479d5d4c4.jpg
#  extracting: /content/idrid/train/2/train1_20_jpg.rf.6e4a2d55ca67c275746fba1c3b8332e2.jpg
#  extracting: /content/idrid/train/2/train1_21_jpg.rf.be206d3500b752647a98f5758a0dd566.jpg
#  extracting: /content/idrid/train/2/train1_22_jpg.rf.2f03d354fd18538a92e4d4d44e78a224.jpg
#  extracting: /content/idrid/train/2/train1_23_jpg.rf.c1d986c329a74686e49a2566f282902b.jpg
#  extracting: /content/idrid/train/2/train1_24_jpg.rf.8043383e0ae10fb5d2e61af52c7553d9.jpg
#  extracting: /content/idrid/train/2/train1_25_jpg.rf.2f560aee6e3984e331329e4ef6fc57d3.jpg
#  extracting: /content/idrid/train/2/train1_26_jpg.rf.b7e48d32bf04290ebe446a4c36fbe0b4.jpg
#  extracting: /content/idrid/train/2/train1_27_jpg.rf.da88a65144c2da55aa6af91a9aba24b9.jpg
#  extracting: /content/idrid/train/2/train1_28_jpg.rf.d6682e5d309125ad2b964033c645fc7a.jpg
#  extracting: /content/idrid/train/2/train1_29_jpg.rf.db30aab6991358ccb0b02f1f717f4e4b.jpg
#  extracting: /content/idrid/train/2/train1_2_jpg.rf.7fb6bc359218ae2ede9cf2e5a5059b3a.jpg
#  extracting: /content/idrid/train/2/train1_30_jpg.rf.d83676f51538f9c5f9e99052b6f08a65.jpg
#  extracting: /content/idrid/train/2/train1_31_jpg.rf.787f98278bf0388135d27ba4572b4317.jpg
#  extracting: /content/idrid/train/2/train1_32_jpg.rf.ef2f51fb6466d85b7316b1e9b112a570.jpg
#  extracting: /content/idrid/train/2/train1_33_jpg.rf.697ef37a7e0d7c3261c278f2e1e3858d.jpg
#  extracting: /content/idrid/train/2/train1_34_jpg.rf.b15e895a5016a50de3a40cc8ded15bd7.jpg
#  extracting: /content/idrid/train/2/train1_35_jpg.rf.bb182fb548305fd7246896da5274a225.jpg
#  extracting: /content/idrid/train/2/train1_36_jpg.rf.0ed95849105d2fbbfa5caa6413c0fdfc.jpg
#  extracting: /content/idrid/train/2/train1_37_jpg.rf.1e517a42c894b23ce493ac14ce7a5fda.jpg
#  extracting: /content/idrid/train/2/train1_38_jpg.rf.6af2bbbfaa68d5c0d792184aef7882ff.jpg
#  extracting: /content/idrid/train/2/train1_39_jpg.rf.6423bd80262154b6aba828e5c3c01b97.jpg
#  extracting: /content/idrid/train/2/train1_3_jpg.rf.707ef7d2c514774fb8e63a372d8b1372.jpg
#  extracting: /content/idrid/train/2/train1_40_jpg.rf.59ceec71ed995e4f967cfa0ccd5f097d.jpg
#  extracting: /content/idrid/train/2/train1_41_jpg.rf.3af05b09dccd633a37398b6169241d8d.jpg
#  extracting: /content/idrid/train/2/train1_42_jpg.rf.ecbce14159448f69911c7b005dcafa90.jpg
#  extracting: /content/idrid/train/2/train1_43_jpg.rf.177f7ce2905a7076e3df396e74600901.jpg
#  extracting: /content/idrid/train/2/train1_44_jpg.rf.90079471f857339203e11a4730647ca9.jpg
#  extracting: /content/idrid/train/2/train1_45_jpg.rf.d38f865fe5125d14484319054a9bf07e.jpg
#  extracting: /content/idrid/train/2/train1_46_jpg.rf.9a8a25eb3a7353e5f31cff411cedefeb.jpg
#  extracting: /content/idrid/train/2/train1_47_jpg.rf.636f6354ba7cdc1f805b666be18577f7.jpg
#  extracting: /content/idrid/train/2/train1_4_jpg.rf.a5862e6a2b90a20496b2ca9d5d82b226.jpg
#  extracting: /content/idrid/train/2/train1_5_jpg.rf.fb22ee6af61a9e8515e1d595edb6ea9e.jpg
#  extracting: /content/idrid/train/2/train1_6_jpg.rf.e8cde37c7d28ee138dad95b5f213966d.jpg
#  extracting: /content/idrid/train/2/train1_7_jpg.rf.c25cd9cee50c2308077405c9043b1f20.jpg
#  extracting: /content/idrid/train/2/train1_8_jpg.rf.6ad1d720e297d88d26dc33fbd265837a.jpg
#  extracting: /content/idrid/train/2/train1_9_jpg.rf.3723bdc87cf6aec17c69895b81cc1a01.jpg

# %% [markdown]
# ## image preprocessing

# %% [markdown]
# ## preprocessing Test

# %% [markdown]
# ## Creating dataloader

# %%
data_transforms = {
    "train": transforms.Compose(
        [
            # transforms.RandomResizedCrop(224),     # uncomment for data augmentation
            # transforms.RandomHorizontalFlip(),     # uncomment for data augmentation
            # transforms.Lambda(load_ben_color_transform_pil),
            # transforms.Resize(224),
            # transforms.CenterCrop(224),
            transforms.ToTensor(),
            # Normalize input channels using mean values and standard deviations of ImageNet.
            # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
    "val": transforms.Compose(
        [
            # transforms.RandomResizedCrop(224),     # uncomment for data augmentation
            # transforms.RandomHorizontalFlip(),     # uncomment for data augmentation
            # transforms.Lambda(load_ben_color_transform_pil),
            # transforms.Resize(224),
            # transforms.CenterCrop(224),
            transforms.ToTensor(),
            # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
}

data_dir = "/content/idrid"
image_datasets = {
    x if x == "train" else "validation": datasets.ImageFolder(
        os.path.join(data_dir, x), data_transforms[x]
    )
    for x in ["train", "val"]
}
dataset_sizes = {x: len(image_datasets[x]) for x in ["train", "validation"]}
class_names = image_datasets["train"].classes

# Initialize dataloader
dataloaders = {
    x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True)
    for x in ["train", "validation"]
}

# function to plot images
def imshow(inp, title=None):
    """Display image from tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    # Inverse of the initial normalization operation.
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)

# %% [markdown]
# Let us show a batch of the test data, just to have an idea of the
# classification problem.

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders["validation"]))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

dataloaders = {
    x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True)
    for x in ["train", "validation"]
}

# %%
len(dataloaders['train'])
# Out:
# 16

# %% [markdown]
# Variational quantum circuit
# ===========================
#
# We first define some quantum layers that will compose the quantum
# circuit.

# %%
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)


def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)


def entangling_layer(nqubits):
    """Layer of CNOTs followed by another shifted layer of CNOT.
    """
    # In other words it should apply something like :
    # CNOT  CNOT  CNOT  CNOT...  CNOT
    #   CNOT  CNOT  CNOT...  CNOT
    for i in range(0, nqubits - 1, 2):  # Loop over even indices: i=0,2,...N-2
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):  # Loop over odd indices:  i=1,3,...N-3
        qml.CNOT(wires=[i, i + 1])

# %% [markdown]
# Now we define the quantum circuit through the PennyLane
# [qnode]{.title-ref} decorator .
#
# The structure is that of a typical variational quantum circuit:
#
# -   **Embedding layer:** All qubits are first initialized in a balanced
#     superposition of *up* and *down* states, then they are rotated
#     according to the input parameters (local embedding).
# -   **Variational layers:** A sequence of trainable rotation layers and
#     constant entangling layers is applied.
# -   **Measurement layer:** For each qubit, the local expectation value
#     of the $Z$ operator is measured. This produces a classical output
#     vector, suitable for additional post-processing.

# %%
@qml.qnode(dev, interface="torch")
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """

    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+> , unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)

    # Embed features in the quantum node
    RY_layer(q_input_features)

    # Sequence of trainable variational layers
    for k in range(q_depth):
        entangling_layer(n_qubits)
        RY_layer(q_weights[k])

    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %% [markdown]
# Dressed quantum circuit
# =======================
#
# We can now define a custom `torch.nn.Module` representing a *dressed*
# quantum circuit.
#
# This is a concatenation of:
#
# -   A classical pre-processing layer (`nn.Linear`).
# -   A classical activation function (`torch.tanh`).
# -   A constant `np.pi/2.0` scaling.
# -   The previously defined quantum circuit (`quantum_net`).
# -   A classical post-processing layer (`nn.Linear`).
#
# The input of the module is a batch of vectors with 512 real parameters
# (features) and the output is a batch of vectors with two real outputs
# (associated with the two classes of images: *ants* and *bees*).

# %%
class DressedQuantumNet(nn.Module):
    """
    Torch module implementing the *dressed* quantum net.
    """

    def __init__(self):
        """
        Definition of the *dressed* layout.
        """

        super().__init__()
        self.pre_net = nn.Linear(2048, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, 3)

    def forward(self, input_features):
        """
        Defining how tensors are supposed to move through the *dressed* quantum
        net.
        """

        # obtain the input features for the quantum circuit
        # by reducing the feature dimension from 512 to 4
        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = torch.hstack(quantum_net(elem, self.q_params)).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %% [markdown]
# ## DressedQunatumNet with softmax layer

# %% [markdown]
# Hybrid classical-quantum model
# ==============================
#
# We are finally ready to build our full hybrid classical-quantum network.
# We follow the *transfer learning* approach:
#
# 1.  First load the classical pre-trained network *ResNet18* from the
#     `torchvision.models` zoo.
# 2.  Freeze all the weights since they should not be trained.
# 3.  Replace the last fully connected layer with our trainable dressed
#     quantum circuit (`DressedQuantumNet`).
#
# ::: {.note}
# ::: {.title}
# Note
# :::
#
# The *ResNet18* model is automatically downloaded by PyTorch and it may
# take several minutes (only the first time).
# :::

# %%
model_hybrid = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.IMAGENET1K_V2)
# feature_size=512
for param in model_hybrid.parameters():
    param.requires_grad = False

# for param in model_hybrid.fc.parameters():
#     param.requires_grad = True
# Notice that model_hybrid.fc is the last layer of ResNet18

model_hybrid.fc = DressedQuantumNet()
# model_hybrid.classifier = DressedQuantumNet()

# Then, unfreeze the last 10 layers
for param in list(model_hybrid.parameters())[-10:]:
    param.requires_grad = True

# Use CUDA or CPU according to the "device" object.
model_hybrid = model_hybrid.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 174MB/s]

# %%
model_hybrid
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): DressedQuantumNet(
#     (pre_net): Linear(in_features=2048, out_features=8, bias=True)
#     (post_net): Linear(in_features=8, out_features=3, bias=True)
#   )
# )

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad:
            continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params += params
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

count_parameters(model_hybrid)
# Out:
# +-----------------------+------------+
# |        Modules        | Parameters |
# +-----------------------+------------+
# |  layer4.2.bn2.weight  |    512     |
# |   layer4.2.bn2.bias   |    512     |
# | layer4.2.conv3.weight |  1048576   |
# |  layer4.2.bn3.weight  |    2048    |
# |   layer4.2.bn3.bias   |    2048    |
# |      fc.q_params      |     32     |
# |   fc.pre_net.weight   |   16384    |
# |    fc.pre_net.bias    |     8      |
# |   fc.post_net.weight  |     24     |
# |    fc.post_net.bias   |     3      |
# +-----------------------+------------+
# Total Trainable Params: 1070147
# 1070147

# %% [markdown]
# # Vgg + Resnet 18

# %% [markdown]
# Training and results
# ====================
#
# Before training the network we need to specify the *loss* function.
#
# We use, as usual in classification problem, the *cross-entropy* which is
# directly available within `torch.nn`.

# %%
criterion = nn.CrossEntropyLoss()
# criterion=nn.BCELoss()

# %% [markdown]
# We also initialize the *Adam optimizer* which is called at each training
# step in order to update the weights of the model.

# %%
optimizer_hybrid = optim.Adam(filter(lambda p: p.requires_grad, model_hybrid.parameters()), lr=step)

# %% [markdown]
# We schedule to reduce the learning rate by a factor of
# `gamma_lr_scheduler` every 10 epochs.

# %%
exp_lr_scheduler = lr_scheduler.StepLR(
    optimizer_hybrid, step_size=10, gamma=gamma_lr_scheduler
)

# %% [markdown]
# What follows is a training function that will be called later. This
# function should return a trained model that can be used to make
# predictions (classifications).

# %%
num_epochs=25

# %%
# just for trying and testing
images_lis=[]
labels_lis=[]
for inputs, labels in dataloaders['train']:
  images_lis.append(inputs)
  labels_lis.append(labels)
  break
image_tensor=images_lis[0][0]
print(image_tensor.shape)

# %% [markdown]
# ## Code for training the model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_loss = 10000.0  # Large arbitrary number
    best_acc_train = 0.0
    best_loss_train = 10000.0  # Large arbitrary number
    print("Training started:")

    for epoch in range(num_epochs):

        # Each epoch has a training and validation phase
        for phase in ["train", "validation"]:
            if phase == "train":
                # Set model to training mode
                model.train()
            else:
                # Set model to evaluate mode
                model.eval()
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            n_batches = dataset_sizes[phase] // batch_size
            it = 0
            for inputs, labels in dataloaders[phase]:
                since_batch = time.time()
                batch_size_ = len(inputs)
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()

                # Track/compute gradient and make an optimization step only when training
                with torch.set_grad_enabled(phase == "train"):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()

                # Print iteration results
                running_loss += loss.item() * batch_size_
                batch_corrects = torch.sum(preds == labels.data).item()
                running_corrects += batch_corrects
                print(
                    "Phase: {} Epoch: {}/{} Iter: {}/{} Batch time: {:.4f}".format(
                        phase,
                        epoch + 1,
                        num_epochs,
                        it + 1,
                        n_batches + 1,
                        time.time() - since_batch,
                    ),
                    end="\r",
                    flush=True,
                )
                it += 1

            # Print epoch results
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
            print(
                "Phase: {} Epoch: {}/{} Loss: {:.4f} Acc: {:.4f}        ".format(
                    "train" if phase == "train" else "validation  ",
                    epoch + 1,
                    num_epochs,
                    epoch_loss,
                    epoch_acc,
                )
            )

            # Check if this is the best model wrt previous epochs
            if phase == "validation" and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == "validation" and epoch_loss < best_loss:
                best_loss = epoch_loss
            if phase == "train" and epoch_acc > best_acc_train:
                best_acc_train = epoch_acc
            if phase == "train" and epoch_loss < best_loss_train:
                best_loss_train = epoch_loss

            # Update learning rate
            if phase == "train":
                scheduler.step()

    # Print final results
    model.load_state_dict(best_model_wts)
    time_elapsed = time.time() - since
    print(
        "Training completed in {:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60)
    )
    print("Best test loss: {:.4f} | Best test accuracy: {:.4f}".format(best_loss, best_acc))
    return model

# %% [markdown]
# We are ready to perform the actual training process.

# %%
model_hybrid = train_model(
    model_hybrid, criterion, optimizer_hybrid, exp_lr_scheduler, num_epochs=num_epochs
)
'''
Resnet18 10 ep -> 0.8636
'''
# Out:
# Training started:
# Phase: train Epoch: 1/25 Loss: 1.0512 Acc: 0.3843
# Phase: validation   Epoch: 1/25 Loss: 0.9482 Acc: 0.5152
# Phase: train Epoch: 2/25 Loss: 0.8716 Acc: 0.6039
# Phase: validation   Epoch: 2/25 Loss: 0.9208 Acc: 0.5455
# Phase: train Epoch: 3/25 Loss: 0.7390 Acc: 0.8627
# Phase: validation   Epoch: 3/25 Loss: 0.8724 Acc: 0.6212
# Phase: train Epoch: 4/25 Loss: 0.6440 Acc: 0.8824
# Phase: validation   Epoch: 4/25 Loss: 0.7328 Acc: 0.7879
# Phase: train Epoch: 5/25 Loss: 0.5588 Acc: 0.9686
# Phase: validation   Epoch: 5/25 Loss: 0.5925 Acc: 0.9394
# Phase: train Epoch: 6/25 Loss: 0.5173 Acc: 0.9569
# Phase: validation   Epoch: 6/25 Loss: 0.4833 Acc: 0.9848
# Phase: train Epoch: 7/25 Loss: 0.4571 Acc: 0.9804
# Phase: validation   Epoch: 7/25 Loss: 0.4257 Acc: 0.9848
# Phase: train Epoch: 8/25 Loss: 0.4095 Acc: 0.9961
# Phase: validation   Epoch: 8/25 Loss: 0.3832 Acc: 0.9848
# Phase: train Epoch: 9/25 Loss: 0.3784 Acc: 0.9961
# Phase: validation   Epoch: 9/25 Loss: 0.3582 Acc: 0.9848
# Phase: train Epoch: 10/25 Loss: 0.3593 Acc: 0.9961
# Phase: validation   Epoch: 10/25 Loss: 0.3404 Acc: 1.0000
# Phase: train Epoch: 11/25 Loss: 0.3475 Acc: 1.0000
# Phase: validation   Epoch: 11/25 Loss: 0.3391 Acc: 1.0000
# Phase: train Epoch: 12/25 Loss: 0.3482 Acc: 1.0000
# Phase: validation   Epoch: 12/25 Loss: 0.3376 Acc: 1.0000
# Phase: train Epoch: 13/25 Loss: 0.3459 Acc: 1.0000
# Phase: validation   Epoch: 13/25 Loss: 0.3363 Acc: 1.0000
# Phase: train Epoch: 14/25 Loss: 0.3428 Acc: 1.0000
# Phase: validation   Epoch: 14/25 Loss: 0.3352 Acc: 1.0000
# Phase: train Epoch: 15/25 Loss: 0.3449 Acc: 0.9961
# Phase: validation   Epoch: 15/25 Loss: 0.3342 Acc: 1.0000
# Phase: train Epoch: 16/25 Loss: 0.3417 Acc: 1.0000
# Phase: validation   Epoch: 16/25 Loss: 0.3329 Acc: 1.0000
# Phase: train Epoch: 17/25 Loss: 0.3406 Acc: 1.0000
# Phase: validation   Epoch: 17/25 Loss: 0.3319 Acc: 1.0000
# Phase: train Epoch: 18/25 Loss: 0.3427 Acc: 0.9961
# Phase: validation   Epoch: 18/25 Loss: 0.3307 Acc: 1.0000
# Phase: train Epoch: 19/25 Loss: 0.3379 Acc: 1.0000
# Phase: validation   Epoch: 19/25 Loss: 0.3295 Acc: 1.0000
# Phase: train Epoch: 20/25 Loss: 0.3367 Acc: 1.0000
# Phase: validation   Epoch: 20/25 Loss: 0.3283 Acc: 1.0000
# Phase: train Epoch: 21/25 Loss: 0.3354 Acc: 1.0000
# Phase: validation   Epoch: 21/25 Loss: 0.3282 Acc: 1.0000
# Phase: train Epoch: 22/25 Loss: 0.3349 Acc: 1.0000
# Phase: validation   Epoch: 22/25 Loss: 0.3281 Acc: 1.0000
# Phase: train Epoch: 23/25 Loss: 0.3389 Acc: 0.9961
# Phase: validation   Epoch: 23/25 Loss: 0.3280 Acc: 1.0000
# Phase: train Epoch: 24/25 Loss: 0.3383 Acc: 0.9961
# Phase: validation   Epoch: 24/25 Loss: 0.3279 Acc: 1.0000
# Phase: train Epoch: 25/25 Loss: 0.3372 Acc: 1.0000
# Phase: validation   Epoch: 25/25 Loss: 0.3279 Acc: 1.0000
# Training completed in 62m 34s
# Best test loss: 0.3279 | Best test accuracy: 1.0000
# '\nResnet50 10 ep -> 0.8636\n'

# %% [markdown]
# We first define a visualization function for a batch of test data.

# %%
torch.save(model_hybrid,"final_model.pth")

# %%
# !mv '/content/final_model.pth' '/content/drive/MyDrive/grid 5.0'

# %%
import pickle
# Save the model
pickle.dump(model_hybrid, open('finalmodel.pkl', 'wb'))

# %% [markdown]
# Visualizing the model predictions
# =================================

# %%
def visualize_model(model, num_images=6, fig_name="Predictions"):
    images_so_far = 0
    _fig = plt.figure(fig_name)
    model.eval()
    with torch.no_grad():
        for _i, (inputs, labels) in enumerate(dataloaders["validation"]):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis("off")
                ax.set_title(f"A-> {labels[j]},P->{class_names[preds[j]]}")
                imshow(inputs.cpu().data[j])
                if images_so_far == num_images:
                    return

# %%
def visualize_model(model, num_images=6, fig_name="Predictions"):
    images_so_far = 0
    _fig = plt.figure(fig_name)
    model.eval()
    with torch.no_grad():
        for _i, (inputs, labels) in enumerate(dataloaders["validation"]):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis("off")
                ax.set_title(f"A->{labels[j]},P->{(class_names[preds[j]])}")
                imshow(inputs.cpu().data[j])
                if images_so_far == num_images:
                    return

# %%
# extracted all the loss and accuracy from above training
trainloss = [1.0512, 0.8716, 0.7390, 0.6440, 0.5588, 0.5173, 0.4571, 0.4095, 0.3784, 0.3593, 0.3475, 0.3482, 0.3459, 0.3428, 0.3449, 0.3417, 0.3406, 0.3427, 0.3379, 0.3367, 0.3354, 0.3349, 0.3389, 0.3383, 0.3372]

trainaccuracy = [0.3843, 0.6039, 0.8627, 0.8824, 0.9686, 0.9569, 0.9804, 0.9961, 0.9961, 0.9961, 1.0000, 1.0000, 1.0000, 1.0000, 0.9961, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.9961, 0.9961]

validationloss= [0.9482, 0.9208, 0.8724, 0.7328, 0.5925, 0.4833, 0.4257, 0.3832, 0.3582, 0.3404, 0.3391, 0.3376, 0.3363, 0.3352, 0.3342, 0.3329, 0.3319, 0.3307, 0.3295, 0.3283, 0.3282, 0.3281, 0.3280, 0.3279, 0.3279]

validationaccuracy= [0.5152, 0.5455, 0.6212, 0.7879, 0.9394, 0.9848, 0.9848, 0.9848, 0.9848, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000]

# %%
import matplotlib.pyplot as plt

# Data
epochs = list(range(1, 26))

# Plotting losses
plt.figure(figsize=(10, 5))
plt.plot(epochs, trainloss, marker='o', label='Training Loss')
plt.plot(epochs, validationloss, marker='o', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plotting accuracies
plt.figure(figsize=(10, 5))
plt.plot(epochs, trainaccuracy, marker='o', label='Training Accuracy')
plt.plot(epochs, validationaccuracy, marker='o', label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Finally, we can run the previous function to see a batch of images with
# the corresponding predictions.

# %%
visualize_model(model_hybrid, num_images=16)
plt.show()

# %% [markdown]
# References
# ==========
#
# \[1\] Andrea Mari, Thomas R. Bromley, Josh Izaac, Maria Schuld, and
# Nathan Killoran. *Transfer learning in hybrid classical-quantum neural
# networks*. arXiv:1912.08278 (2019).
#
# \[2\] Rajat Raina, Alexis Battle, Honglak Lee, Benjamin Packer, and
# Andrew Y Ng. *Self-taught learning: transfer learning from unlabeled
# data*. Proceedings of the 24th International Conference on Machine
# Learning\*, 759--766 (2007).
#
# \[3\] Kaiming He, Xiangyu Zhang, Shaoqing ren and Jian Sun. *Deep
# residual learning for image recognition*. Proceedings of the IEEE
# Conference on Computer Vision and Pattern Recognition, 770-778 (2016).
#
# \[4\] Ville Bergholm, Josh Izaac, Maria Schuld, Christian Gogolin,
# Carsten Blank, Keri McKiernan, and Nathan Killoran. *PennyLane:
# Automatic differentiation of hybrid quantum-classical computations*.
# arXiv:1811.04968 (2018).
#
# About the author
#
# AstroHackers Team
#
#
# ================
